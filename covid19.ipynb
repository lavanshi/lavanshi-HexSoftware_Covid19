# %%
import pandas as pd

import numpy as np

import seaborn as sns

import matplotlib.pyplot as plt

# %%
data=pd.read_csv("D:/csv/covid19.csv")

# %%
data.head()
# Out:
#    Unnamed: 0        date state  hospitalized_with_symptoms  intensive_care  \
# 0           0  24-02-2020   ITA                         101              26
# 1           1  25-02-2020   ITA                         114              35
# 2           2  26-02-2020   ITA                         128              36
# 3           3  27-02-2020   ITA                         248              56
# 4           4  28-02-2020   ITA                         345              64
#
#    total_hospitalized  home_quarantine  total_confirmed_cases  \
# 0                 127               94                    221
# 1                 150              162                    311
# 2                 164              221                    385
# 3                 304              284                    588
# 4                 409              412                    821
#
#    new_confirmed_cases  recovered  death  total_cases  swabs_made
# 0                  221          1      7          229        4324
# 1                   90          1     10          322        8623
# 2                   74          3     12          400        9587
# 3                  203         45     17          650       12014
# 4                  233         46     21          888       15695

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'date', 'state', 'hospitalized_with_symptoms',
#        'intensive_care', 'total_hospitalized', 'home_quarantine',
#        'total_confirmed_cases', 'new_confirmed_cases', 'recovered', 'death',
#        'total_cases', 'swabs_made'],
#       dtype='object')

# %%
data.tail()
# Out:
#     Unnamed: 0        date state  hospitalized_with_symptoms  intensive_care  \
# 30          30  25-03-2020   ITA                       23112            3489
# 31          31  26-03-2020   ITA                       24753            3612
# 32          32  27-03-2020   ITA                       26029            3732
# 33          33  28-03-2020   ITA                       26676            3856
# 34          34  29-03-2020   ITA                       27386            3906
#
#     total_hospitalized  home_quarantine  total_confirmed_cases  \
# 30               26601            30920                  57521
# 31               28365            33648                  62013
# 32               29761            36653                  66414
# 33               30532            39533                  70065
# 34               31292            42588                  73880
#
#     new_confirmed_cases  recovered  death  total_cases  swabs_made
# 30                 3491       9362   7503        74386      324445
# 31                 4492      10361   8165        80539      361060
# 32                 4401      10950   9134        86498      394079
# 33                 3651      12384  10023        92472      429526
# 34                 3815      13030  10779        97689      454030

# %%
data.describe()
# Out:
#        Unnamed: 0  hospitalized_with_symptoms  intensive_care  \
# count   35.000000                   35.000000       35.000000
# mean    17.000000                 9742.600000     1539.228571
# std     10.246951                 9320.218169     1364.064581
# min      0.000000                  101.000000       26.000000
# 25%      8.500000                 1190.000000      262.000000
# 50%     17.000000                 6650.000000     1153.000000
# 75%     25.500000                16864.000000     2756.000000
# max     34.000000                27386.000000     3906.000000
#
#        total_hospitalized  home_quarantine  total_confirmed_cases  \
# count           35.000000        35.000000              35.000000
# mean         11281.857143     11466.942857           22748.771429
# std          10680.802798     13293.109179           23848.957586
# min            127.000000        94.000000             221.000000
# 25%           1452.000000      1030.000000            2484.500000
# 50%           7803.000000      5036.000000           12839.000000
# 75%          19620.000000     20650.500000           40270.500000
# max          31292.000000     42588.000000           73880.000000
#
#        new_confirmed_cases     recovered         death   total_cases  \
# count            35.000000     35.000000     35.000000     35.000000
# mean           2110.857143   3341.657143   2646.942857  28737.371429
# std            1637.750414   4034.089386   3306.511730  31140.590349
# min              74.000000      1.000000      7.000000    229.000000
# 25%             485.500000    218.000000     93.000000   2795.500000
# 50%            2116.000000   1258.000000   1016.000000  15113.000000
# 75%            3631.500000   5600.500000   4428.500000  50299.500000
# max            4821.000000  13030.000000  10779.000000  97689.000000
#
#           swabs_made
# count      35.000000
# mean   137260.485714
# std    134884.899167
# min      4324.000000
# 25%     27846.500000
# 50%     86011.000000
# 75%    220054.000000
# max    454030.000000

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                    0
# date                          0
# state                         0
# hospitalized_with_symptoms    0
# intensive_care                0
# total_hospitalized            0
# home_quarantine               0
# total_confirmed_cases         0
# new_confirmed_cases           0
# recovered                     0
# death                         0
# total_cases                   0
# swabs_made                    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'date', 'state', 'hospitalized_with_symptoms',
#        'intensive_care', 'total_hospitalized', 'home_quarantine',
#        'total_confirmed_cases', 'new_confirmed_cases', 'recovered', 'death',
#        'total_cases', 'swabs_made'],
#       dtype='object')

# %%
#relating the variable with scatterplots

# %%
sns.relplot(x="total_cases",y="recovered", data= data)

# %%
sns.relplot(x="total_cases",y="total_confirmed_cases", data= data)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'date', 'state', 'hospitalized_with_symptoms',
#        'intensive_care', 'total_hospitalized', 'home_quarantine',
#        'total_confirmed_cases', 'new_confirmed_cases', 'recovered', 'death',
#        'total_cases', 'swabs_made'],
#       dtype='object')

# %%
sns.relplot(x="hospitalized_with_symptoms",y="total_confirmed_cases", data= data)

# %%
sns.relplot(x="total_confirmed_cases",y="hospitalized_with_symptoms",hue="recovered" ,data= data)

# %%
sns.pairplot(data)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'date', 'state', 'hospitalized_with_symptoms',
#        'intensive_care', 'total_hospitalized', 'home_quarantine',
#        'total_confirmed_cases', 'new_confirmed_cases', 'recovered', 'death',
#        'total_cases', 'swabs_made'],
#       dtype='object')

# %%
sns.relplot(x="total_cases",y="home_quarantine", kind="line",data=data)

# %%
sns.relplot(x="recovered",y="home_quarantine", kind="line",data=data)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'date', 'state', 'hospitalized_with_symptoms',
#        'intensive_care', 'total_hospitalized', 'home_quarantine',
#        'total_confirmed_cases', 'new_confirmed_cases', 'recovered', 'death',
#        'total_cases', 'swabs_made'],
#       dtype='object')

# %%
sns.catplot(x="recovered",y="total_cases",data=data)

# %%
sns.relplot(x="total_cases",y="total_hospitalized",kind="line",data=data)
